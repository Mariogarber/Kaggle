# %%
import pandas as pd 

data = pd.read_csv('earthquakes_scaled.csv', index_col="index")

data.drop(columns=['Unnamed: 0'], inplace=True)

data
# Out:
#             magnitude      time   updated         felt  cdi  mmi  tsunami  \
# index
# us6000lcz2   0.055556 -0.815799 -0.977412    -0.083333 -0.6 -1.0      0.0
# us6000n9xs  -1.000000  0.289580  0.000423    -0.083333 -0.6  0.0      0.0
# tx2024mydx  -0.888889  0.289510  0.349996    -0.083333 -0.6  0.0      0.0
# us6000n9xf  -0.833333  0.289510  0.000343    -0.083333 -0.6  0.0      0.0
# nn00880145  -1.000000  0.278268  0.311118    -0.083333 -0.6 -1.0      0.0
# ...               ...       ...       ...          ...  ...  ...      ...
# ci40731623  -0.338889  0.580644  0.377703   774.583333  0.4  1.0      1.0
# ci40699207  -0.505556  0.455449  0.368965  1009.375000  0.4  1.0      1.0
# ci40699207  -0.505556  0.455449  0.368965  1009.375000  0.4  1.0      1.0
# ok2024cish  -0.133333 -0.323356  0.356419  1101.333333  0.8  3.0      0.0
# ok2024cish  -0.133333 -0.323356  0.356419  1101.333333  0.8  3.0      0.0
#
# ...
