# %%
import pandas as pd
import numpy as np
import keras as kr

data = pd.read_csv('earthquakes_scaled_class.csv', index_col="index")

data
# Out:
#             magnitude      time   updated         felt  cdi  mmi  tsunami  \
# index
# us6000lcz2          5 -0.815799 -0.977412    -0.083333 -0.6 -1.0      0.0
# us6000n9xs          4  0.289580  0.000423    -0.083333 -0.6  0.0      0.0
# tx2024mydx          4  0.289510  0.349996    -0.083333 -0.6  0.0      0.0
# us6000n9xf          4  0.289510  0.000343    -0.083333 -0.6  0.0      0.0
# nn00880145          4  0.278268  0.311118    -0.083333 -0.6 -1.0      0.0
# ...               ...       ...       ...          ...  ...  ...      ...
# ci40731623          5  0.580644  0.377703   774.583333  0.4  1.0      1.0
# ci40699207          4  0.455449  0.368965  1009.375000  0.4  1.0      1.0
# ci40699207          4  0.455449  0.368965  1009.375000  0.4  1.0      1.0
# ok2024cish          5 -0.323356  0.356419  1101.333333  0.8  3.0      0.0
# ok2024cish          5 -0.323356  0.356419  1101.333333  0.8  3.0      0.0
#
# ...
